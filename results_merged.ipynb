# %% [markdown]
# # Results with Merged Dataset
# #### Q5: For all of the models that were produced in 2008 that are still being produced now, how much has the mpg improved and which vehicle improved the most?
# Remember to use your new dataset, `combined_dataset.csv`. You should've created this data file in the previous section: *Merging Datasets*.

# %%
# load dataset
import pandas as pd
df = pd.read_csv('combined_dataset.csv')
df
# Out:
#              model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0             ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 1             ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 2               AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 3               AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 4               AUDI A3         2.0         4    Auto-S6        2WD  Gasoline
# 5               AUDI A3         2.0         4    Auto-S6        2WD  Gasoline
# 6               AUDI A3         3.2         6    Auto-S6        4WD  Gasoline
# 7               AUDI A3         3.2         6    Auto-S6        4WD  Gasoline
# 8               AUDI A4         2.0         4    Auto-AV        2WD  Gasoline
# 9               AUDI A4         2.0         4    Auto-AV        2WD  Gasoline
# 10              AUDI A4         3.1         6      Man-6        4WD  Gasoline
# ...

# %%
df[['cmb_mpg_2008','cmb_mpg']]
# Out:
#      cmb_mpg_2008  cmb_mpg
# 0            19.0     23.0
# 1            19.0     22.0
# 2            24.0     27.0
# 3            24.0     29.0
# 4            25.0     27.0
# 5            25.0     29.0
# 6            21.0     27.0
# 7            21.0     29.0
# 8            24.0     27.0
# 9            24.0     27.0
# 10           19.0     27.0
# 11           19.0     27.0
# 12           20.0     27.0
# 13           20.0     27.0
# 14           21.0     27.0
# 15           21.0     27.0
# 16           20.0     28.0
# 17           20.0     26.0
# 18           20.0     23.0
# 19           21.0     28.0
# 20           21.0     26.0
# 21           21.0     23.0
# 22           18.0     28.0
# 23           18.0     26.0
# 24           18.0     23.0
# 25           18.0     22.0
# 26           15.0     22.0
# 27           16.0     21.0
# 28           16.0     21.0
# 29           14.0     21.0
# ..            ...      ...
# 892          22.0     29.0
# 893          22.0     26.0
# ...

# %% [markdown]
# ### 1. Create a new dataframe, `model_mpg`, that contain the mean combined mpg values in 2008 and 2018 for each unique model
#
# To do this, group by `model` and find the mean `cmb_mpg_2008` and mean `cmb_mpg` for each.

# %%
model_mpg = df.groupby('model_2008').mean()[['cmb_mpg_2008','cmb_mpg']]

# %%
model_mpg.head(20)
# Out:
#                         cmb_mpg_2008    cmb_mpg
# model_2008
# ACURA RDX                  19.000000  22.500000
# AUDI A3                    23.333333  28.000000
# AUDI A4                    21.000000  27.000000
# AUDI A6                    19.666667  25.666667
# AUDI A8 L                  16.500000  22.000000
# AUDI Q7                    15.000000  21.000000
# AUDI S4                    15.500000  24.000000
# AUDI S5                    16.000000  24.000000
# AUDI TT Coupe              21.666667  26.000000
# AUDI TT Roadster           21.333333  26.000000
# BMW 750i                   20.000000  19.500000
# BMW Alpina B7              18.000000  19.000000
# BMW M6 Convertible         14.000000  16.500000
# CADILLAC CTS               20.000000  22.800000
# CADILLAC Escalade          14.000000  17.000000
# CHEVROLET Corvette         18.000000  17.750000
# CHEVROLET Equinox          19.000000  27.833333
# CHEVROLET Impala           20.500000  21.250000
# ...

# %% [markdown]
# ### 2. Create a new column, `mpg_change`, with the change in mpg
# Subtract the mean mpg in 2008 from that in 2018 to get the change in mpg

# %%
model_mpg['mpg_change'] =model_mpg.cmb_mpg-model_mpg.cmb_mpg_2008

# %%
model_mpg.head()
# Out:
#             cmb_mpg_2008    cmb_mpg  mpg_change
# model_2008
# ACURA RDX      19.000000  22.500000    3.500000
# AUDI A3        23.333333  28.000000    4.666667
# AUDI A4        21.000000  27.000000    6.000000
# AUDI A6        19.666667  25.666667    6.000000
# AUDI A8 L      16.500000  22.000000    5.500000

# %% [markdown]
# ### 3. Find the vehicle that improved the most
# Find the max mpg change, and then use query or indexing to see what model it is!

# %%
max_mpg = model_mpg.mpg_change.max()
max_mpg
# Out:
# 16.533333333333339

# %%
max_model=model_mpg.query('mpg_change == @max_mpg')

# %%
max_model
# Out:
#              cmb_mpg_2008  cmb_mpg  mpg_change
# model_2008
# VOLVO XC 90     15.666667     32.2   16.533333

# %%
max_model_m2=model_mpg[model_mpg['mpg_change']==max_mpg]
max_model_m2
# Out:
#              cmb_mpg_2008  cmb_mpg  mpg_change
# model_2008
# VOLVO XC 90     15.666667     32.2   16.533333
